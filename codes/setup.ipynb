# %% [markdown]
# # Csomag függőségek telepítése

# %%
# !pip install pyarrow

# %%
pip install fastparquet

# %%
# !pip install huggingface_hub

# %%
# !pip install scikit-learn

# %%
# !pip install transformers

# %%
# !pip install llama-index
# Out:
# Collecting llama-index
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# alpaca-trade-api 3.1.1 requires aiohttp==3.8.2, but you have aiohttp 3.10.10 which is incompatible.
# alpaca-py 0.13.6 requires websockets<12.0.0,>=11.0.3, but you have websockets 10.4 which is incompatible.
#   Downloading llama_index-0.11.20-py3-none-any.whl (6.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48
#   Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl (1.2 MB)
# Collecting llama-index-indices-managed-llama-cloud>=0.3.0
#   Downloading llama_index_indices_managed_llama_cloud-0.4.0-py3-none-any.whl (10 kB)
# Collecting llama-index-core<0.12.0,>=0.11.20
#   Downloading llama_index_core-0.11.20-py3-none-any.whl (1.6 MB)
# Collecting llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0
#   Downloading llama_index_multi_modal_llms_openai-0.2.3-py3-none-any.whl (5.9 kB)
# Collecting llama-index-question-gen-openai<0.3.0,>=0.2.0
#   Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl (2.9 kB)
# Collecting llama-index-cli<0.4.0,>=0.3.1
#   Downloading llama_index_cli-0.3.1-py3-none-any.whl (27 kB)
# Collecting llama-index-program-openai<0.3.0,>=0.2.0
#   Downloading llama_index_program_openai-0.2.0-py3-none-any.whl (5.3 kB)
# Collecting llama-index-agent-openai<0.4.0,>=0.3.4
#   Downloading llama_index_agent_openai-0.3.4-py3-none-any.whl (13 kB)
# Collecting nltk>3.8.1
#   Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Collecting llama-index-embeddings-openai<0.3.0,>=0.2.4
#   Downloading llama_index_embeddings_openai-0.2.5-py3-none-any.whl (6.1 kB)
# Collecting llama-index-readers-llama-parse>=0.3.0
#   Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl (2.5 kB)
# Collecting llama-index-llms-openai<0.3.0,>=0.2.10
#   Downloading llama_index_llms_openai-0.2.16-py3-none-any.whl (13 kB)
# Collecting llama-index-readers-file<0.3.0,>=0.2.0
#   Downloading llama_index_readers_file-0.2.2-py3-none-any.whl (38 kB)
# Collecting openai>=1.14.0
#   Downloading openai-1.52.2-py3-none-any.whl (386 kB)
# Collecting pillow>=9.0.0
#   Downloading pillow-11.0.0-cp39-cp39-win_amd64.whl (2.6 MB)
# Collecting networkx>=3.0
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: requests>=2.31.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (2.31.0)
# Collecting typing-inspect>=0.8.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: wrapt in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (1.12.1)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (6.0.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (4.9.0)
# Collecting dirtyjson<2.0.0,>=1.0.8
#   Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Collecting tqdm<5.0.0,>=4.66.1
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
# Collecting tiktoken>=0.3.3
#   Downloading tiktoken-0.8.0-cp39-cp39-win_amd64.whl (884 kB)
# Collecting nest-asyncio<2.0.0,>=1.5.8
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Collecting httpx
#   Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
# Collecting SQLAlchemy[asyncio]>=1.4.49
#   Downloading SQLAlchemy-2.0.36-cp39-cp39-win_amd64.whl (2.1 MB)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.2.0
#   Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Collecting pydantic<3.0.0,>=2.7.0
#   Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Collecting dataclasses-json
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting aiohttp<4.0.0,>=3.8.6
#   Downloading aiohttp-3.10.10-cp39-cp39-win_amd64.whl (381 kB)
# Requirement already satisfied: numpy<2.0.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.20->llama-index) (1.26.3)
# Collecting deprecated>=1.2.9.3
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting yarl<2.0,>=1.12.0
#   Downloading yarl-1.16.0-cp39-cp39-win_amd64.whl (89 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (21.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.3.1)
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (5.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.20->llama-index) (4.0.3)
# Collecting llama-cloud>=0.0.11
#   Downloading llama_cloud-0.1.4-py3-none-any.whl (176 kB)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
# Requirement already satisfied: sniffio in c:\users\lrobert\anaconda3\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.2.0)
# Requirement already satisfied: certifi in c:\users\lrobert\anaconda3\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.20->llama-index) (2021.10.8)
# Requirement already satisfied: idna in c:\users\lrobert\anaconda3\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.20->llama-index) (3.2)
# Requirement already satisfied: anyio in c:\users\lrobert\anaconda3\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.20->llama-index) (2.2.0)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: pandas in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.1.4)
# Collecting pypdf<5.0.0,>=4.0.1
#   Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
# Collecting striprtf<0.0.27,>=0.0.26
#   Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.3
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lrobert\anaconda3\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.2.1)
# Collecting llama-parse>=0.5.0
#   Downloading llama_parse-0.5.11-py3-none-any.whl (13 kB)
# Collecting click<9.0.0,>=8.1.7
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Requirement already satisfied: colorama in c:\users\lrobert\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.7->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.3.0->llama-index) (0.4.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lrobert\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index) (2021.8.3)
# Requirement already satisfied: joblib in c:\users\lrobert\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index) (1.1.0)
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.6.1-cp39-none-win_amd64.whl (202 kB)
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting anyio
#   Downloading anyio-4.6.2.post1-py3-none-any.whl (90 kB)
# Collecting typing-extensions>=4.5.0
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting pydantic-core==2.23.4
#   Downloading pydantic_core-2.23.4-cp39-none-win_amd64.whl (1.9 MB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lrobert\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.20->llama-index) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lrobert\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.20->llama-index) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lrobert\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.26.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lrobert\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.20->llama-index) (1.1.1)
# Collecting regex>=2021.8.3
#   Downloading regex-2024.9.11-cp39-cp39-win_amd64.whl (274 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lrobert\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.20->llama-index) (0.4.3)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.0-cp39-cp39-win_amd64.whl (45 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.23.0-py3-none-any.whl (49 kB)
# Requirement already satisfied: packaging>=17.0 in c:\users\lrobert\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.20->llama-index) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\lrobert\anaconda3\lib\site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.20->llama-index) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lrobert\anaconda3\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2021.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lrobert\anaconda3\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2023.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lrobert\anaconda3\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\lrobert\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)
# Installing collected packages: typing-extensions, propcache, h11, exceptiongroup, yarl, typing-inspect, tqdm, SQLAlchemy, regex, pydantic-core, marshmallow, httpcore, click, anyio, aiohappyeyeballs, tiktoken, tenacity, pydantic, pillow, nltk, networkx, nest-asyncio, jiter, httpx, fsspec, distro, dirtyjson, deprecated, dataclasses-json, aiohttp, openai, llama-index-core, llama-index-llms-openai, llama-index-agent-openai, striprtf, pypdf, llama-parse, llama-index-program-openai, llama-index-embeddings-openai, llama-cloud, beautifulsoup4, llama-index-readers-llama-parse, llama-index-readers-file, llama-index-question-gen-openai, llama-index-multi-modal-llms-openai, llama-index-legacy, llama-index-indices-managed-llama-cloud, llama-index-cli, llama-index
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.9.0
#     Uninstalling typing-extensions-4.9.0:
#       Successfully uninstalled typing-extensions-4.9.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.9.4
#     Uninstalling yarl-1.9.4:
#       Successfully uninstalled yarl-1.9.4
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Uninstalling tqdm-4.62.3:
#       Successfully uninstalled tqdm-4.62.3
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 1.4.22
#     Uninstalling SQLAlchemy-1.4.22:
#       Successfully uninstalled SQLAlchemy-1.4.22
#   Attempting uninstall: regex
#     Found existing installation: regex 2021.8.3
#     Uninstalling regex-2021.8.3:
#       Successfully uninstalled regex-2021.8.3
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic-core 2.14.6
#     Uninstalling pydantic-core-2.14.6:
#       Successfully uninstalled pydantic-core-2.14.6
#   Attempting uninstall: click
#     Found existing installation: click 8.0.3
#     Uninstalling click-8.0.3:
#       Successfully uninstalled click-8.0.3
#   Attempting uninstall: anyio
#     Found existing installation: anyio 2.2.0
#     Uninstalling anyio-2.2.0:
#       Successfully uninstalled anyio-2.2.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.6.5
#     Uninstalling nltk-3.6.5:
#       Successfully uninstalled nltk-3.6.5
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.6.3
#     Uninstalling networkx-2.6.3:
#       Successfully uninstalled networkx-2.6.3
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.5.1
#     Uninstalling nest-asyncio-1.5.1:
#       Successfully uninstalled nest-asyncio-1.5.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2021.10.1
#     Uninstalling fsspec-2021.10.1:
#       Successfully uninstalled fsspec-2021.10.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.2
#     Uninstalling aiohttp-3.8.2:
#       Successfully uninstalled aiohttp-3.8.2
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.10.0
#     Uninstalling beautifulsoup4-4.10.0:
#       Successfully uninstalled beautifulsoup4-4.10.0
# Successfully installed SQLAlchemy-2.0.36 aiohappyeyeballs-2.4.3 aiohttp-3.10.10 anyio-4.6.2.post1 beautifulsoup4-4.12.3 click-8.1.7 dataclasses-json-0.6.7 deprecated-1.2.14 dirtyjson-1.0.8 distro-1.9.0 exceptiongroup-1.2.2 fsspec-2024.10.0 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 jiter-0.6.1 llama-cloud-0.1.4 llama-index-0.11.20 llama-index-agent-openai-0.3.4 llama-index-cli-0.3.1 llama-index-core-0.11.20 llama-index-embeddings-openai-0.2.5 llama-index-indices-managed-llama-cloud-0.4.0 llama-index-legacy-0.9.48.post3 llama-index-llms-openai-0.2.16 llama-index-multi-modal-llms-openai-0.2.3 llama-index-program-openai-0.2.0 llama-index-question-gen-openai-0.2.0 llama-index-readers-file-0.2.2 llama-index-readers-llama-parse-0.3.0 llama-parse-0.5.11 marshmallow-3.23.0 nest-asyncio-1.6.0 networkx-3.2.1 nltk-3.9.1 openai-1.52.2 pillow-11.0.0 propcache-0.2.0 pydantic-2.9.2 pydantic-core-2.23.4 pypdf-4.3.1 regex-2024.9.11 striprtf-0.0.26 tenacity-8.5.0 tiktoken-0.8.0 tqdm-4.66.5 typing-extensions-4.12.2 typing-inspect-0.9.0 yarl-1.16.0

# %%
# !pip install llama-index-embeddings-huggingface
# Out:
# Collecting llama-index-embeddings-huggingface
#   Downloading llama_index_embeddings_huggingface-0.3.1-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-embeddings-huggingface) (0.11.20)
# Collecting huggingface-hub[inference]>=0.19.0
#   Downloading huggingface_hub-0.26.1-py3-none-any.whl (447 kB)
# Collecting sentence-transformers>=2.6.1
#   Downloading sentence_transformers-3.2.1-py3-none-any.whl (255 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lrobert\anaconda3\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.10.0)
# Requirement already satisfied: requests in c:\users\lrobert\anaconda3\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.31.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\lrobert\anaconda3\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (21.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lrobert\anaconda3\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\lrobert\anaconda3\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.66.5)
# Requirement already satisfied: filelock in c:\users\lrobert\anaconda3\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lrobert\anaconda3\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.12.2)
# Requirement already satisfied: aiohttp in c:\users\lrobert\anaconda3\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.10.10)
# Requirement already satisfied: dataclasses-json in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: wrapt in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.12.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.26.3)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.2.14)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (8.5.0)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (11.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (2.0.36)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (2.9.2)
# Requirement already satisfied: httpx in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.27.2)
# Requirement already satisfied: nltk>3.8.1 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (3.9.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (3.2.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (5.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (21.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.4.3)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lrobert\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (2024.9.11)
# Requirement already satisfied: click in c:\users\lrobert\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (8.1.7)
# Requirement already satisfied: joblib in c:\users\lrobert\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\lrobert\anaconda3\lib\site-packages (from packaging>=20.9->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.0.4)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\lrobert\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lrobert\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lrobert\anaconda3\lib\site-packages (from requests->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lrobert\anaconda3\lib\site-packages (from requests->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lrobert\anaconda3\lib\site-packages (from requests->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.26.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lrobert\anaconda3\lib\site-packages (from requests->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.0.4)
# Collecting torch>=1.11.0
#   Downloading torch-2.5.0-cp39-cp39-win_amd64.whl (203.0 MB)
# Requirement already satisfied: scipy in c:\users\lrobert\anaconda3\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.7.1)
# Requirement already satisfied: scikit-learn in c:\users\lrobert\anaconda3\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.24.2)
# Collecting transformers<5.0.0,>=4.41.0
#   Downloading transformers-4.46.0-py3-none-any.whl (10.0 MB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lrobert\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.1.1)
# Collecting sympy==1.13.1
#   Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Requirement already satisfied: jinja2 in c:\users\lrobert\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.11.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lrobert\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.2.1)
# Requirement already satisfied: colorama in c:\users\lrobert\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.4.4)
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.4.5-cp39-none-win_amd64.whl (286 kB)
# Collecting tokenizers<0.21,>=0.20
#   Downloading tokenizers-0.20.1-cp39-none-win_amd64.whl (2.4 MB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lrobert\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lrobert\anaconda3\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lrobert\anaconda3\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (3.23.0)
# Requirement already satisfied: httpcore==1.* in c:\users\lrobert\anaconda3\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\lrobert\anaconda3\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: anyio in c:\users\lrobert\anaconda3\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (4.6.2.post1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lrobert\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\lrobert\anaconda3\lib\site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-huggingface) (1.2.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lrobert\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lrobert\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.2.0)
# Collecting numpy<2.0.0
#   Downloading numpy-1.22.4-cp39-cp39-win_amd64.whl (14.7 MB)
# Installing collected packages: numpy, huggingface-hub, tokenizers, sympy, safetensors, transformers, torch, sentence-transformers, llama-index-embeddings-huggingface
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.3
#     Uninstalling numpy-1.26.3:
#       Successfully uninstalled numpy-1.26.3
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.9
#     Uninstalling sympy-1.9:
#       Successfully uninstalled sympy-1.9
# Successfully installed huggingface-hub-0.26.1 llama-index-embeddings-huggingface-0.3.1 numpy-1.22.4 safetensors-0.4.5 sentence-transformers-3.2.1 sympy-1.13.1 tokenizers-0.20.1 torch-2.5.0 transformers-4.46.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# numba 0.54.1 requires numpy<1.21,>=1.17, but you have numpy 1.22.4 which is incompatible.
# alpaca-trade-api 3.1.1 requires aiohttp==3.8.2, but you have aiohttp 3.10.10 which is incompatible.
# alpaca-py 0.13.6 requires websockets<12.0.0,>=11.0.3, but you have websockets 10.4 which is incompatible.

# %%
# !pip install llama-index-embeddings-instructor
# Out:
# Collecting llama-index-embeddings-instructor
#   Downloading llama_index_embeddings_instructor-0.2.1-py3-none-any.whl (3.6 kB)
# Collecting instructorembedding<2.0.0,>=1.0.1
#   Downloading InstructorEmbedding-1.0.1-py2.py3-none-any.whl (19 kB)
# Collecting sentence-transformers<3.0.0,>=2.2.2
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
# Requirement already satisfied: torch<3.0.0,>=2.1.2 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-embeddings-instructor) (2.5.0)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-embeddings-instructor) (0.11.20)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (2.0.36)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.6.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (2.31.0)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.0.8)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.2.14)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (4.12.2)
# Requirement already satisfied: dataclasses-json in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (0.6.7)
# Requirement already satisfied: wrapt in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.12.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (8.5.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (3.10.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (4.66.5)
# Requirement already satisfied: nltk>3.8.1 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.22.4)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (6.0.1)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (0.8.0)
# Requirement already satisfied: httpx in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (0.27.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (11.0.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (0.9.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (2.9.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (2024.10.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\lrobert\anaconda3\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (3.2.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (4.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (21.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (2.4.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lrobert\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (5.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lrobert\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (2024.9.11)
# Requirement already satisfied: joblib in c:\users\lrobert\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.1.0)
# Requirement already satisfied: click in c:\users\lrobert\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (8.1.7)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\lrobert\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lrobert\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lrobert\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (2021.10.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lrobert\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lrobert\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lrobert\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (3.2)
# Requirement already satisfied: scipy in c:\users\lrobert\anaconda3\lib\site-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (1.7.1)
# Requirement already satisfied: scikit-learn in c:\users\lrobert\anaconda3\lib\site-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (0.24.2)
# Requirement already satisfied: huggingface-hub>=0.15.1 in c:\users\lrobert\anaconda3\lib\site-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (0.26.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in c:\users\lrobert\anaconda3\lib\site-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (4.46.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\lrobert\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (21.0)
# Requirement already satisfied: filelock in c:\users\lrobert\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (3.3.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\lrobert\anaconda3\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (3.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lrobert\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.1.1)
# Requirement already satisfied: jinja2 in c:\users\lrobert\anaconda3\lib\site-packages (from torch<3.0.0,>=2.1.2->llama-index-embeddings-instructor) (2.11.3)
# Requirement already satisfied: sympy==1.13.1 in c:\users\lrobert\anaconda3\lib\site-packages (from torch<3.0.0,>=2.1.2->llama-index-embeddings-instructor) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lrobert\anaconda3\lib\site-packages (from sympy==1.13.1->torch<3.0.0,>=2.1.2->llama-index-embeddings-instructor) (1.2.1)
# Requirement already satisfied: colorama in c:\users\lrobert\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (0.4.4)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\lrobert\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (0.20.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\lrobert\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (0.4.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\lrobert\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (0.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lrobert\anaconda3\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (0.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\lrobert\anaconda3\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (3.23.0)
# Requirement already satisfied: httpcore==1.* in c:\users\lrobert\anaconda3\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\lrobert\anaconda3\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.2.0)
# Requirement already satisfied: anyio in c:\users\lrobert\anaconda3\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (4.6.2.post1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lrobert\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\lrobert\anaconda3\lib\site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-instructor) (1.2.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lrobert\anaconda3\lib\site-packages (from jinja2->torch<3.0.0,>=2.1.2->llama-index-embeddings-instructor) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lrobert\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (2.2.0)
# Installing collected packages: sentence-transformers, instructorembedding, llama-index-embeddings-instructor
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.2.1
#     Uninstalling sentence-transformers-3.2.1:
#       Successfully uninstalled sentence-transformers-3.2.1
# Successfully installed instructorembedding-1.0.1 llama-index-embeddings-instructor-0.2.1 sentence-transformers-2.7.0

# %%
# !pip install nltk

# %%
# !pip install tqdm

# %%
# !pip install -qU langchain-text-splitters

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Obtaining dependency information for evaluate from https://files.pythonhosted.org/packages/a2/e7/cbca9e2d2590eb9b5aa8f7ebabe1beb1498f9462d2ecede5c9fd9735faaf/evaluate-0.4.3-py3-none-any.whl.metadata
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting datasets>=2.0.0 (from evaluate)
#   Obtaining dependency information for datasets>=2.0.0 from https://files.pythonhosted.org/packages/20/bd/db3d92897ba528d62facd936a5dc1cf867e174323036a632724ab0bc1946/datasets-3.0.2-py3-none-any.whl.metadata
#   Downloading datasets-3.0.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from evaluate) (1.25.2)
# Collecting dill (from evaluate)
#   Obtaining dependency information for dill from https://files.pythonhosted.org/packages/46/d1/e73b6ad76f0b1fb7f23c35c6d95dbc506a9c8804f43dda8cb5b0fa6331fd/dill-0.3.9-py3-none-any.whl.metadata
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from evaluate) (2.1.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from evaluate) (4.66.1)
# Collecting xxhash (from evaluate)
#   Obtaining dependency information for xxhash from https://files.pythonhosted.org/packages/52/1c/fa3b61c0cf03e1da4767213672efe186b1dfa4fc901a4a694fb184a513d1/xxhash-3.5.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading xxhash-3.5.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess (from evaluate)
#   Obtaining dependency information for multiprocess from https://files.pythonhosted.org/packages/b2/07/8cbb75d6cfbe8712d8f7f6a5615f083c6e710ab916b748fbb20373ddb142/multiprocess-0.70.17-py311-none-any.whl.metadata
#   Downloading multiprocess-0.70.17-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from evaluate) (0.25.1)
# Requirement already satisfied: packaging in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from evaluate) (23.2)
# Requirement already satisfied: filelock in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from datasets>=2.0.0->evaluate) (3.15.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Collecting dill (from evaluate)
#   Obtaining dependency information for dill from https://files.pythonhosted.org/packages/c9/7a/cef76fd8438a42f96db64ddaa85280485a9c395e7df3db8158cfec1eee34/dill-0.3.8-py3-none-any.whl.metadata
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting requests>=2.19.0 (from evaluate)
#   Obtaining dependency information for requests>=2.19.0 from https://files.pythonhosted.org/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl.metadata
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.62.1 (from evaluate)
#   Obtaining dependency information for tqdm>=4.62.1 from https://files.pythonhosted.org/packages/48/5d/acf5905c36149bbaec41ccf7f2b68814647347b72075ac0b1fe3022fdc73/tqdm-4.66.5-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB ? eta 0:00:00
# Collecting multiprocess (from evaluate)
#   Obtaining dependency information for multiprocess from https://files.pythonhosted.org/packages/50/15/b56e50e8debaf439f44befec5b2af11db85f6e0f344c3113ae0be0593a91/multiprocess-0.70.16-py311-none-any.whl.metadata
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: aiohttp in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from datasets>=2.0.0->evaluate) (3.10.10)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from requests>=2.19.0->evaluate) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from requests>=2.19.0->evaluate) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from requests>=2.19.0->evaluate) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from pandas->evaluate) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.16.0)
# Requirement already satisfied: six>=1.5 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\opell\anaconda3\envs\nlp\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.0.0->evaluate) (0.2.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ---------------------------------------- 0.0/84.0 kB ? eta -:--:--
#    ---------------------------------------- 84.0/84.0 kB 4.9 MB/s eta 0:00:00
# Downloading datasets-3.0.2-py3-none-any.whl (472 kB)
#    ---------------------------------------- 0.0/472.7 kB ? eta -:--:--
#    ------------------- -------------------- 225.3/472.7 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  471.0/472.7 kB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 472.7/472.7 kB 4.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ---------------------------------------- 0.0/116.3 kB ? eta -:--:--
#    ---------------------------------------- 116.3/116.3 kB 6.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.5 kB ? eta -:--:--
#    ---------------------------------------- 143.5/143.5 kB 8.9 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB ? eta 0:00:00
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.4 kB ? eta -:--:--
#    ---------------------------------------- 78.4/78.4 kB 4.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-win_amd64.whl (30 kB)
# Installing collected packages: xxhash, tqdm, requests, dill, multiprocess, datasets, evaluate
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# Successfully installed datasets-3.0.2 dill-0.3.8 evaluate-0.4.3 multiprocess-0.70.16 requests-2.32.3 tqdm-4.66.5 xxhash-3.5.0
